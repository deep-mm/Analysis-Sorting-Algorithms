# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )
#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
#plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'runtime' ],   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'runtime' ],   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime' )
plt . title ( 'Sorting Algorithms - Runtime' )
plt . legend ()
plt . show ()
# Out:
#           n  comparison  runtime
# 0    100000     1839424      0.0
# 1    200000     3885889      0.0
# 2    300000     6156220      0.0
# 3    400000     8728536      0.0
# 4    500000    10641161      0.0
# 5    600000    12704974      0.0
# 6    700000    15436332      0.0
# 7    800000    17615491      1.0
# 8    900000    20497148      1.0
# 9   1000000    22779575      1.0
# 10  1100000    24468081      1.0
# 11  1200000    27504828      2.0
# 12  1300000    29872396      2.0
# 13  1400000    32116337      2.0
# 14  1500000    35224798      2.0
# 15  1600000    37114609      3.0
# 16  1700000    40657033      3.0
# 17  1800000    42131110      3.0
# 18  1900000    45247151      4.0
# 19  2000000    47387339     10.0
# 20  2100000    50145890      4.0
# 21  2200000    52242106      4.0
# 22  2300000    55106791      5.0
# 23  2400000    58870767      5.0
# 24  2500000    59616025      5.0
# 25  2600000    63808672      6.0
# 26  2700000    66676424      6.0
# 27  2800000    68629215      6.0
# 28  2900000    69865641      6.0
# 29  3000000    73803697      6.0
# 30  3100000    74653354      7.0
# 31  3200000    79232302      7.0
# 32  3300000    80180565      8.0
# 33  3400000    83180387      8.0
# 34  3500000    85154408      9.0
# 35  3600000    91011937      9.0
# 36  3700000    90499247      9.0
# 37  3800000    94193677      9.0
#           n  comparison  runtime
# 0    100000     1540740      0.0
# 1    200000     3281770      0.0
# 2    300000     5099010      0.0
# 3    400000     6962581      0.0
# 4    500000     8862244      0.0
# 5    600000    10797809      0.0
# 6    700000    12754305      0.0
# 7    800000    14725219      0.0
# 8    900000    16719803      0.0
# 9   1000000    18725490      0.0
# 10  1100000    20749440      0.0
# 11  1200000    22796067      1.0
# 12  1300000    24844632      1.0
# 13  1400000    26908899      1.0
# 14  1500000    28974902      1.0
# 15  1600000    31050447      1.0
# 16  1700000    33146016      1.0
# 17  1800000    35241424      2.0
# 18  1900000    37342612      2.0
# 19  2000000    39449097      6.0
# 20  2100000    41557591      2.0
# 21  2200000    43700592      2.0
# 22  2300000    45842870      3.0
# 23  2400000    47989316      3.0
# 24  2500000    50140904      3.0
# 25  2600000    52292615      3.0
# 26  2700000    54454864      3.0
# 27  2800000    56617928      3.0
# 28  2900000    58783057      4.0
# 29  3000000    60951113      4.0
# 30  3100000    63120340      3.0
# 31  3200000    65301112      3.0
# 32  3300000    67496097      4.0
# 33  3400000    69689415      5.0
# 34  3500000    71885004      5.0
# 35  3600000    74082884      5.0
# 36  3700000    76281759      5.0
# 37  3800000    78486749      6.0
