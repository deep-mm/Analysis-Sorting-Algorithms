# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )
#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
#plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'runtime' ],   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'runtime' ],   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime' )
plt . title ( 'Sorting Algorithms - Runtime' )
plt . legend ()
plt . show ()
# Out:
#            n  comparison  runtime
# 0     100000     1859194      0.0
# 1     200000     4033441      0.0
# 2     300000     6162818      0.0
# 3     400000     8385865      0.0
# 4     500000    10882598      0.0
# ..       ...         ...      ...
# 95   9600000   263962265     15.0
# 96   9700000   255379307     14.0
# 97   9800000   258590687     15.0
# 98   9900000   265719384     14.0
# 99  10000000   263371662     14.0
#
# [100 rows x 3 columns]
#            n  comparison  runtime
# 0     100000     1541160      0.0
# 1     200000     3281291      0.0
# 2     300000     5098602      0.0
# 3     400000     6962175      0.0
# 4     500000     8861595      0.0
# ..       ...         ...      ...
# 95   9600000   211160844      6.0
# 96   9700000   213515515      7.0
# 97   9800000   215864323      7.0
# 98   9900000   218215055      7.0
# 99  10000000   220566041      7.0
#
# [100 rows x 3 columns]

# %%
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )
#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
#plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'comparison' ]/1000000,   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'comparison' ]/1000000,   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'comparisons/1000000' )
plt . title ( 'Sorting Algorithms - Comparisons' )
plt . legend ()
plt . show ()
# Out:
#            n  comparison  runtime
# 0     100000     1859194      0.0
# 1     200000     4033441      0.0
# 2     300000     6162818      0.0
# 3     400000     8385865      0.0
# 4     500000    10882598      0.0
# ..       ...         ...      ...
# 95   9600000   263962265     15.0
# 96   9700000   255379307     14.0
# 97   9800000   258590687     15.0
# 98   9900000   265719384     14.0
# 99  10000000   263371662     14.0
#
# [100 rows x 3 columns]
#            n  comparison  runtime
# 0     100000     1541160      0.0
# 1     200000     3281291      0.0
# 2     300000     5098602      0.0
# 3     400000     6962175      0.0
# 4     500000     8861595      0.0
# ..       ...         ...      ...
# 95   9600000   211160844      6.0
# 96   9700000   213515515      7.0
# 97   9800000   215864323      7.0
# 98   9900000   218215055      7.0
# 99  10000000   220566041      7.0
#
# [100 rows x 3 columns]

# %%
# Read the csv files
insertion   =   pd . read_csv ( 'insertion.csv' )
print ( insertion )
# Plot the graphs
plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime' )
plt . title ( 'Insertion Sort - Runtime' )
plt . legend ()
plt . show ()

# %%
# Read the csv files
insertion   =   pd . read_csv ( 'insertion.csv' )
#print ( insertion )
# Plot the graphs
plt . plot ( insertion [ 'n' ],   insertion [ 'comparison' ]/1000000,   label = 'Insertion Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'comparisons/1000000' )
plt . title ( 'Insertion Sort - Comparison' )
plt . legend ()
plt . show ()

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )

# Add a column for runtime multiplied by 1000 per comparison
#insertion [ 'rc' ]   =   insertion [ 'runtime' ]   *   1000   /   insertion [ 'comparison' ]
quick [ 'rc' ]   =   quick [ 'runtime' ] * 1000  /   quick [ 'comparison' ]
merge [ 'rc' ]   =   merge [ 'runtime' ] * 1000  /   merge [ 'comparison' ]

#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
# Make y axis runtime per comparison
#plt . plot ( insertion [ 'n' ],   insertion [ 'rc' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'rc' ],   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'rc' ],   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime/comparison' )
plt . title ( 'Sorting Algorithms - Runtime' )
plt . legend ()
plt . show ()
# Out:
#            n  comparison  runtime        rc
# 0     100000     1859194      0.0  0.000000
# 1     200000     4033441      0.0  0.000000
# 2     300000     6162818      0.0  0.000000
# 3     400000     8385865      0.0  0.000000
# 4     500000    10882598      0.0  0.000000
# ..       ...         ...      ...       ...
# 95   9600000   263962265     15.0  0.000057
# 96   9700000   255379307     14.0  0.000055
# 97   9800000   258590687     15.0  0.000058
# 98   9900000   265719384     14.0  0.000053
# 99  10000000   263371662     14.0  0.000053
#
# [100 rows x 4 columns]
#            n  comparison  runtime        rc
# 0     100000     1541160      0.0  0.000000
# 1     200000     3281291      0.0  0.000000
# 2     300000     5098602      0.0  0.000000
# 3     400000     6962175      0.0  0.000000
# 4     500000     8861595      0.0  0.000000
# ..       ...         ...      ...       ...
# 95   9600000   211160844      6.0  0.000028
# 96   9700000   213515515      7.0  0.000033
# ...

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
insertion   =   pd . read_csv ( 'insertion.csv' )

# Add a column for runtime multiplied by 1000 per comparison
insertion [ 'rc' ]   =   insertion [ 'runtime' ]   *   1000   /   insertion [ 'comparison' ]

print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
# Make y axis runtime per comparison
plt . plot ( insertion [ 'n' ],   insertion [ 'rc' ],   label = 'Insertion Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime/comparison' )
plt . title ( 'Sorting Algorithms - Runtime' )
plt . legend ()
plt . show ()
# Out:
#          n  comparison  runtime        rc
# 0     1000      258459      0.0  0.000000
# 1     2000     1017522      0.0  0.000000
# 2     3000     2211377      0.0  0.000000
# 3     4000     3985100      0.0  0.000000
# 4     5000     6246778      0.0  0.000000
# ..     ...         ...      ...       ...
# 95   96000  2303763717     30.0  0.000013
# 96   97000  2347773578     30.0  0.000013
# 97   98000  2393621827     32.0  0.000013
# 98   99000  2451947872     38.0  0.000015
# 99  100000  2502304695     33.0  0.000013
#
# [100 rows x 4 columns]
#            n  comparison  runtime        rc
# 0     100000     1859194      0.0  0.000000
# 1     200000     4033441      0.0  0.000000
# 2     300000     6162818      0.0  0.000000
# 3     400000     8385865      0.0  0.000000
# 4     500000    10882598      0.0  0.000000
# ..       ...         ...      ...       ...
# 95   9600000   263962265     15.0  0.000057
# 96   9700000   255379307     14.0  0.000055
# ...

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
insertion   =   pd . read_csv ( 'insertion_block.csv' )
quick   =   pd . read_csv ( 'quick_block.csv' )
merge   =   pd . read_csv ( 'merge_block.csv' )
# Update the first column to be the block size from 1 to 10001 in steps of 1000
insertion [ 'n' ]   =   np . arange ( 1 ,   10001 ,   100 )
quick [ 'n' ]   =   np . arange ( 1 ,   10001 ,   100 )
merge [ 'n' ]   =   np . arange ( 1 ,   10001 ,   100 )

print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
# Make y axis runtime per comparison
plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'runtime' ],   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'runtime' ],   label = 'Merge Sort' )
plt . xlabel ( 'block size' )
plt . ylabel ( 'runtime (ms)' )
plt . title ( 'Sorting Algorithms - Runtime - n (10000)' )
plt . legend ()
plt . show ()
# Out:
#        n  comparison  runtime
# 0      1        9999      5.0
# 1    101      262235     17.0
# 2    201      508526     39.0
# 3    301      762664     29.0
# 4    401     1009850     28.0
# ..   ...         ...      ...
# 95  9501    22654969    466.0
# 96  9601    23227042    545.0
# 97  9701    23324622    521.0
# 98  9801    24085798    586.0
# 99  9901    24571613    539.0
#
# [100 rows x 3 columns]
#        n  comparison  runtime
# 0      1      123869     73.0
# 1    101      163466     85.0
# 2    201      153768     52.0
# 3    301      152159     68.0
# 4    401      153485     70.0
# ..   ...         ...      ...
# 95  9501      145052    104.0
# 96  9601      156561     84.0
# 97  9701      146312     49.0
# 98  9801      147695     52.0
# 99  9901      151616    164.0
#
# [100 rows x 3 columns]
#        n  comparison  runtime
# 0      1       62742     44.0
# 1    101       89768     23.0
# 2    201       94678     11.0
# 3    301       98115     25.0
# ...

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
insertion   =   pd . read_csv ( 'insertion_k.csv' )
quick   =   pd . read_csv ( 'quick_k.csv' )

print ( insertion )
print ( quick )
# Plot the graphs
# Make y axis runtime per comparison
plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
plt . plot ( quick [ 'n' ],   quick [ 'runtime' ],   label = 'Quick Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime (ms)' )
plt . title ( 'Sorting Algorithms - Runtime - Finding K' )
plt . legend ()
plt . show ()
# Out:
#           n  comparison  runtime
# 0     10000     2511254     43.0
# 1     20000     4980650     42.0
# 2     30000     7561271     43.0
# 3     40000    10040841     56.0
# 4     50000    12510249     61.0
# ..      ...         ...      ...
# 95   960000   240785075    843.0
# 96   970000   242987311    862.0
# 97   980000   245572610   1148.0
# 98   990000   247906898    912.0
# 99  1000000   250842024    916.0
#
# [100 rows x 3 columns]
#           n  comparison  runtime
# 0     10000      154578     65.0
# 1     20000      332962     70.0
# 2     30000      505994     86.0
# 3     40000      685746     92.0
# 4     50000      931716    125.0
# ..      ...         ...      ...
# 95   960000    23126766    556.0
# 96   970000    23696736    586.0
# 97   980000    24350854    881.0
# 98   990000    24409486    646.0
# 99  1000000    24738794    704.0
#
# [100 rows x 3 columns]

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )
#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
#plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
# log n
plt . plot ( quick [ 'n' ],   quick [ 'runtime' ]/(quick [ 'n' ] * np . log2 ( quick [ 'n' ])),   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'runtime' ]/(merge [ 'n' ] * np . log2 ( merge [ 'n' ])),   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime/nlgn' )
plt . title ( 'Sorting Algorithms - Runtime/nlgn' )
plt . legend ()
plt . show ()
# Out:
#            n  comparison  runtime
# 0     100000     1859194      0.0
# 1     200000     4033441      0.0
# 2     300000     6162818      0.0
# 3     400000     8385865      0.0
# 4     500000    10882598      0.0
# ..       ...         ...      ...
# 95   9600000   263962265     15.0
# 96   9700000   255379307     14.0
# 97   9800000   258590687     15.0
# 98   9900000   265719384     14.0
# 99  10000000   263371662     14.0
#
# [100 rows x 3 columns]
#            n  comparison  runtime
# 0     100000     1541160      0.0
# 1     200000     3281291      0.0
# 2     300000     5098602      0.0
# 3     400000     6962175      0.0
# 4     500000     8861595      0.0
# ..       ...         ...      ...
# 95   9600000   211160844      6.0
# 96   9700000   213515515      7.0
# 97   9800000   215864323      7.0
# 98   9900000   218215055      7.0
# 99  10000000   220566041      7.0
#
# [100 rows x 3 columns]

# %%
import   pandas   as   pd
import   matplotlib.pyplot   as   plt
import   numpy   as   np
# Read the csv files
#insertion   =   pd . read_csv ( 'insertion.csv' )
quick   =   pd . read_csv ( 'quick.csv' )
merge   =   pd . read_csv ( 'merge.csv' )
#print ( insertion )
print ( quick )
print ( merge )
# Plot the graphs
#plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ],   label = 'Insertion Sort' )
# log n
plt . plot ( quick [ 'n' ],   quick [ 'comparison' ]/(quick [ 'n' ] * np . log2 ( quick [ 'n' ])),   label = 'Quick Sort' )
plt . plot ( merge [ 'n' ],   merge [ 'comparison' ]/(merge [ 'n' ] * np . log2 ( merge [ 'n' ])),   label = 'Merge Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'comparison/nlgn' )
plt . title ( 'Sorting Algorithms - Comparison/nlgn' )
plt . legend ()
plt . show ()
# Out:
#            n  comparison  runtime
# 0     100000     1859194      0.0
# 1     200000     4033441      0.0
# 2     300000     6162818      0.0
# 3     400000     8385865      0.0
# 4     500000    10882598      0.0
# ..       ...         ...      ...
# 95   9600000   263962265     15.0
# 96   9700000   255379307     14.0
# 97   9800000   258590687     15.0
# 98   9900000   265719384     14.0
# 99  10000000   263371662     14.0
#
# [100 rows x 3 columns]
#            n  comparison  runtime
# 0     100000     1541160      0.0
# 1     200000     3281291      0.0
# 2     300000     5098602      0.0
# 3     400000     6962175      0.0
# 4     500000     8861595      0.0
# ..       ...         ...      ...
# 95   9600000   211160844      6.0
# 96   9700000   213515515      7.0
# 97   9800000   215864323      7.0
# 98   9900000   218215055      7.0
# 99  10000000   220566041      7.0
#
# [100 rows x 3 columns]

# %%
# Read the csv files
insertion   =   pd . read_csv ( 'insertion.csv' )
print ( insertion )
# Plot the graphs
plt . plot ( insertion [ 'n' ],   insertion [ 'runtime' ]/(insertion [ 'n' ] * insertion [ 'n' ]),   label = 'Insertion Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'runtime/n^2' )
plt . title ( 'Insertion Sort - Runtime/n^2' )
plt . legend ()
plt . show ()
# Out:
#          n  comparison  runtime
# 0     1000      258459      0.0
# 1     2000     1017522      0.0
# 2     3000     2211377      0.0
# 3     4000     3985100      0.0
# 4     5000     6246778      0.0
# ..     ...         ...      ...
# 95   96000  2303763717     30.0
# 96   97000  2347773578     30.0
# 97   98000  2393621827     32.0
# 98   99000  2451947872     38.0
# 99  100000  2502304695     33.0
#
# [100 rows x 3 columns]

# %%
# Read the csv files
insertion   =   pd . read_csv ( 'insertion.csv' )
print ( insertion )
# Plot the graphs
plt . plot ( insertion [ 'n' ],   insertion [ 'comparison' ]/(insertion [ 'n' ] * insertion [ 'n' ]),   label = 'Insertion Sort' )
plt . xlabel ( 'input size' )
plt . ylabel ( 'comparison/n^2' )
plt . title ( 'Insertion Sort - Comparison/n^2' )
plt . legend ()
plt . show ()
# Out:
#          n  comparison  runtime
# 0     1000      258459      0.0
# 1     2000     1017522      0.0
# 2     3000     2211377      0.0
# 3     4000     3985100      0.0
# 4     5000     6246778      0.0
# ..     ...         ...      ...
# 95   96000  2303763717     30.0
# 96   97000  2347773578     30.0
# 97   98000  2393621827     32.0
# 98   99000  2451947872     38.0
# 99  100000  2502304695     33.0
#
# [100 rows x 3 columns]
